# %%
network_size = 256
for i in range(0,network_size):
#     when 0 => f <= "ram_data0.txt";
    if i<10:
        print('when ', i ,  '=> f <= "ram_data00' , i , '.txt";' , sep='') 
    elif i<100:
        print('when ', i ,  '=> f <= "ram_data0' , i , '.txt";' , sep='') 
    else:
        print('when ', i ,  '=> f <= "ram_data' , i , '.txt";' , sep='')
# Out:
# when 0=> f <= "ram_data000.txt";
# when 1=> f <= "ram_data001.txt";
# when 2=> f <= "ram_data002.txt";
# when 3=> f <= "ram_data003.txt";
# when 4=> f <= "ram_data004.txt";
# when 5=> f <= "ram_data005.txt";
# when 6=> f <= "ram_data006.txt";
# when 7=> f <= "ram_data007.txt";
# when 8=> f <= "ram_data008.txt";
# when 9=> f <= "ram_data009.txt";
# when 10=> f <= "ram_data010.txt";
# when 11=> f <= "ram_data011.txt";
# when 12=> f <= "ram_data012.txt";
# when 13=> f <= "ram_data013.txt";
# when 14=> f <= "ram_data014.txt";
# when 15=> f <= "ram_data015.txt";
# when 16=> f <= "ram_data016.txt";
# when 17=> f <= "ram_data017.txt";
# when 18=> f <= "ram_data018.txt";
# when 19=> f <= "ram_data019.txt";
# when 20=> f <= "ram_data020.txt";
# when 21=> f <= "ram_data021.txt";
# when 22=> f <= "ram_data022.txt";
# when 23=> f <= "ram_data023.txt";
# when 24=> f <= "ram_data024.txt";
# when 25=> f <= "ram_data025.txt";
# when 26=> f <= "ram_data026.txt";
# when 27=> f <= "ram_data027.txt";
# ...
